# %%
# %matplotlib inline
import math
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l

# %%
batch_size, num_steps = 32, 35
train_iter, vocab = d2l.load_data_time_machine(batch_size, num_steps, token_name='char')

# %% [markdown]
# LSTM 的实现和 GRU基本类似，改动在初始化状态的时候多加一个记忆单元 C 的初始化，以及 `forward` 函数的公式变化，其他基本一致，因此只展示简洁实现

# %%
num_inputs, num_hiddens = len(vocab), 256 
lstm_layer = nn.LSTM(num_inputs, num_hiddens)
model = d2l.RNNLM(lstm_layer, len(vocab))
model = model.to(d2l.try_gpu())
d2l.train_ch8(model, train_iter, vocab, 0.01, 10, d2l.try_gpu())
# Out:
# d:\Software\work\conda\miniconda\envs\pytorch\lib\site-packages\torch\nn\modules\lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       3 model = d2l.RNNLM(lstm_layer, len(vocab))
#       4 model = model.to(d2l.try_gpu())
# ----> 5 d2l.train_ch8(model, train_iter, vocab, 0.01, 10, d2l.try_gpu())
#
# File d:\Software\work\conda\miniconda\envs\pytorch\lib\site-packages\d2l\torch.py:1738, in train_ch8(net, train_iter, vocab, lr, num_epochs, device, use_random_iter)
#    1736 # 训练和预测
#    1737 for epoch in range(num_epochs):
# -> 1738     ppl, speed = train_epoch_ch8(
#    1739         net, train_iter, loss, updater, device, use_random_iter)
# ...

# %% [markdown]
# > 由于 `d2l` 有问题，不能运行，之后看看能否解决
